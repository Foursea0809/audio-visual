# %% [markdown]
# <a href="https://colab.research.google.com/github/Foursea0809/audio-visual/blob/main/train_av.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Dedicated GPU-only audio-visual (AV) TM-CTC training entry point for VoxMM."""
from train_voxmm import main


if __name__ == "__main__":
    main("av")
